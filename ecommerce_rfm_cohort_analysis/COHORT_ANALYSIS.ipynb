# %%
import pandas as pd
import numpy as np
import plotly.express as px
import koreanize_matplotlib
import seaborn as sns

# %%
cohort = pd.read_csv('COHORT_PROMOTION_ANALYSIS.csv',encoding='utf8')
cohort
# Out:
#    is_promotion week_range   cnt
# 0             0      1.W-0  1000
# 1             0      2.W-1   239
# 2             0      3.W-2    83
# 3             0      4.W-3    46
# 4             0      5.W-4    32
# 5             1      1.W-0  1000
# 6             1      2.W-1   440
# 7             1      3.W-2   159
# 8             1      4.W-3    97
# 9             1      5.W-4    70

# %% [markdown]
# ## **1. 첫구매 프로모션 적용여부에 따른 주차별 리텐션 분석**
# ***

# %%
fig = sns.lineplot(cohort, x='week_range',y='cnt',hue='is_promotion')
fig.set_title('첫구매 프로모션 적용여부에 따른 리텐션(미적용: 0, 적용: 1)')
fig.set_xlabel('주차')
fig.set_ylabel('리텐션')
fig
# Out:
# <Axes: title={'center': '첫구매 프로모션 적용여부에 따른 리텐션(미적용: 0, 적용: 1)'}, xlabel='주차', ylabel='리텐션'>

# %%
cohort['retention_rate'] = 100 * cohort['cnt'] / 1000
cohort
# Out:
#    is_promotion week_range   cnt  retention_rate
# 0             0      1.W-0  1000           100.0
# 1             0      2.W-1   239            23.9
# 2             0      3.W-2    83             8.3
# 3             0      4.W-3    46             4.6
# 4             0      5.W-4    32             3.2
# 5             1      1.W-0  1000           100.0
# 6             1      2.W-1   440            44.0
# 7             1      3.W-2   159            15.9
# 8             1      4.W-3    97             9.7
# 9             1      5.W-4    70             7.0
